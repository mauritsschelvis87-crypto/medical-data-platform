# %% [markdown]
# # Load Synthea CSV Files
#
# This notebook only loads the raw Synthea CSV files.
# No normalization is applied here yet.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path(r"C:\Users\mauri\Projects\medical-data-platform\apps\ai-service")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from app.services.synthea_csv_loader import DEFAULT_SYNTHEA_CSV_DIR, load_synthea_csv_tables

# %%
csv_dir = DEFAULT_SYNTHEA_CSV_DIR
csv_dir

# %%
tables = load_synthea_csv_tables(csv_dir)
list(tables.keys())

# %%
patients = tables["patients"]
encounters = tables["encounters"]
observations = tables["observations"]
medications = tables["medications"]

# %%
patients.head()

# %%
patients.shape, encounters.shape, observations.shape, medications.shape

# %%
patients.columns.tolist()
